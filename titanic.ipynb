# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Initialisation

# %% [markdown]
# 1) Importez les bibliothèques suivantes :
# - Pandas
# - NumPy
# - Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %% [markdown]
# 2) Depuis la bibliothèque scikit-learn (sklearn), importez les fonctions correspondant aux algorithmes de Machine Learning que vous souhaitez utiliser. Par exemple :
# - Random Forest
# - Logistic Regression
# - SVM
# - K-nearest Neighbours
# ...

# %%
from sklearn import svm
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# 3) A l'aide de la fonction read_csv de Pandas, chargez train.csv dans un DataFrame. Faites de même avec test.csv, puis affichez les 5 premières lignes de chaque DataFrame.

# %%
datatrain = pd.read_csv("/home/User_TP1/Downloads/train.csv")
datatrain.head()

Datatraintest = pd. read_csv ('/home/User_TP1/Downloads/test.csv')
Datatraintest.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# 4) Constituez votre DataFrame d'apprentissage avec les colonnes numériques :
# - Age
# - Pclass
# - Fare

# %%
datatrain2 = datatrain[['Age', 'Pclass', 'Fare']]
datatrain2.head()
# Out:
#    Age  Pclass     Fare
# 0   22       3   7.2500
# 1   38       1  71.2833
# 2   26       3   7.9250
# 3   35       1  53.1000
# 4   35       3   8.0500

# %% [markdown]
# 5) Remplacez les NaN de votre DataFrame par la valeur de votre choix, en utilisant la fonction fillna de Pandas

# %%
datatrain2['Age']=datatrain2['Age'].fillna(datatrain2['Age'].mean())
datatrain2
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#            Age  Pclass      Fare
# 0    22.000000       3    7.2500
# 1    38.000000       1   71.2833
# 2    26.000000       3    7.9250
# 3    35.000000       1   53.1000
# 4    35.000000       3    8.0500
# 5    29.699118       3    8.4583
# 6    54.000000       1   51.8625
# 7     2.000000       3   21.0750
# 8    27.000000       3   11.1333
# 9    14.000000       2   30.0708
# 10    4.000000       3   16.7000
# 11   58.000000       1   26.5500
# 12   20.000000       3    8.0500
# 13   39.000000       3   31.2750
# 14   14.000000       3    7.8542
# 15   55.000000       2   16.0000
# 16    2.000000       3   29.1250
# 17   29.699118       2   13.0000
# 18   31.000000       3   18.0000
# 19   29.699118       3    7.2250
# 20   35.000000       2   26.0000
# 21   34.000000       2   13.0000
# 22   15.000000       3    8.0292
# ...

# %% [markdown]
# 6) A partir du DataFrame obtenu, afficher les valeurs minimale, maximale et médiane du champ Fare.

# %%
datatrain3 = datatrain2[['Fare']]
print datatrain3.median()
print datatrain3.max()
print datatrain3.min()
# Out:
# Fare    14.4542
# dtype: float64
# Fare    512.3292
# dtype: float64
# Fare    0
# dtype: float64

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# 7) A partir de scikit-learn (sklearn), importez la librairie cross_validation. Grâce à la fonction train_test_split, divisez votre training set en 4 jeux de données distincts pour Cross Validation : X_train, y_train, X_cv, y_cv.

# %%
from sklearn.cross_validation import train_test_split

X_train, y_train, X_cv, y_cv = train_test_split(datatrain2, datatrain['Survived'])

# %% [markdown]
# 8) Afficher la forme (nombre de lignes et de colonnes) des 4 jeux de données obtenus, grâce à la fonction shape.

# %%
print X_train.shape, '\n'; print y_train.shape, '\n';print X_cv.shape, '\n';print y_cv.shape
# Out:
# (668, 3)
#
# (223, 3)
#
# (668,)
#
# (223,)

# %% [markdown]
# ## Model Training

# %% [markdown]
# 9) Entraînez, à l'aide de l'algorithme de votre choix, un premier modèle sur vos features et vos labels de training : X_train, y_train.

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 600)
model.fit(X_train, X_cv)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=2, n_estimators=600, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0)

# %% [markdown]
# 10) Affichez le score obtenu par votre modèle sur vos features et labels de Cross Validation (CV), à l'aide de la fonction score.

# %%
model.score(y_train,y_cv)
# Out:
# 0.70852017937219736

# %% [markdown]
# 11) Utilisez votre modèle pour faire une première prédiction sur votre test set, à l'aide de la fonction predict_proba.

# %% [markdown]
# ## Export

# %% [markdown]
# 12) Exportez vos données au format CSV grâce à la fonction to_csv de Pandas. Le résultat doit comporter 1 ligne d'en-tête + 418 lignes suivant le format suivant :
#
# PassengerId,Survived
#
# 12345,0.92
#
# 67890,0.04

# %%
--------------------------TP2------------------------------------------------

# %% [markdown]
# I) Age de distribution

# %%
import pylab as py
datatrain['Age'].hist()
py.show()

# %% [markdown]
# II) Survival per class:

# %%
Data_Pclass_Survived = datatrain[['Pclass','Survived']]
Data_Pclass_Survived
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# 5         3         0
# 6         1         0
# 7         3         0
# 8         3         1
# 9         2         1
# 10        3         1
# 11        1         1
# 12        3         0
# 13        3         0
# 14        3         0
# 15        2         1
# 16        3         0
# 17        2         1
# 18        3         0
# 19        3         1
# 20        2         0
# 21        2         1
# 22        3         1
# 23        1         1
# 24        3         0
# 25        3         1
# 26        3         0
# 27        1         0
# 28        3         1
# 29        3         0
# ..      ...       ...
# 861       2         0
# 862       1         1
# 863       3         0
# 864       2         0
# 865       2         1
# 866       2         1
# 867       1         0
# 868       3         0
# 869       3         1
# ...

# %% [markdown]
# III)

# %%
import matplotlib
plt_1=Data_Pclass_Survived.groupby('Pclass').Survived.sum()
plt_2=Data_Pclass_Survived.groupby('Pclass').Survived.count()
plt_3=plt_1/plt_2
plt_3
# Out:
# Pclass
# 1         0.629630
# 2         0.472826
# 3         0.242363
# Name: Survived, dtype: float64

# %%
IV

# %%
datatr = datatrain[['SibSp', 'Parch']]
datatr['relatives'] = datatr['SibSp']+datatr['Parch']
datatr
# Out:
#      SibSp  Parch  relatives
# 0        1      0          1
# 1        1      0          1
# 2        0      0          0
# 3        1      0          1
# 4        0      0          0
# 5        0      0          0
# 6        0      0          0
# 7        3      1          4
# 8        0      2          2
# 9        1      0          1
# 10       1      1          2
# 11       0      0          0
# 12       0      0          0
# 13       1      5          6
# 14       0      0          0
# 15       0      0          0
# 16       4      1          5
# 17       0      0          0
# 18       1      0          1
# 19       0      0          0
# 20       0      0          0
# 21       0      0          0
# 22       0      0          0
# 23       0      0          0
# 24       3      1          4
# 25       1      5          6
# 26       0      0          0
# 27       3      2          5
# 28       0      0          0
# 29       0      0          0
# ..     ...    ...        ...
# ...

# %%
#question 5
tr = pd.DataFrame(datatrain['Name'].str.extract("[\,]+([^\.]+)"), columns=['Name'])
tr['Name'].value_counts()
# Out:
#  Mr              517
#  Miss            182
#  Mrs             125
#  Master           40
#  Dr                7
#  Rev               6
#  Major             2
#  Col               2
#  Mlle              2
#  Jonkheer          1
#  Ms                1
#  Sir               1
#  Don               1
#  Mme               1
#  Capt              1
#  Lady              1
#  the Countess      1
# dtype: int64

# %%
#question 6
tr2 = pd.DataFrame(datatrain['Name'].str.extract("([A-Za-z0-9]+)"), columns=['Name'])
tr2.groupby('Name').size()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-eb0d32725959> in <module>()
#       1 #question 6
#       2 tr2 = pd.DataFrame(datatrain['Name'].str.extract("([A-Za-z0-9]+)"), columns=['Name'])
# ----> 3 tr2.groupby('Name').value_count()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     486
#     487         raise AttributeError("%r object has no attribute %r" %
# --> 488                              (type(self).__name__, attr))
#     489
#     490     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_count'
